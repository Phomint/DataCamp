# %% [markdown]
# ## Fine-tuning
# ![image.png](attachment:4c6fe069-8864-4dc1-823b-5864cfea821d.png)

# %% [markdown]
# ## Full fine-tuning
# - The entire model weights are updated
# - Computationally expensive
# ![image.png](attachment:c7bf2837-c0ac-4edf-b3af-6588fd093752.png)

# %% [markdown]
# ## Partial fine-tuning
# - Some layers are fixed
# - Only task-specific layers are updated
# ![image.png](attachment:4d97b131-f7b7-4eee-b7ed-d386c122430a.png)

# %% [markdown]
# ## Transfer Learning
# - A pre-trained model is adapted to a different but related task
# - Leverages knowledge from one domain to a related one
# ![image.png](attachment:c906f29c-854e-4c72-b0e9-a645a84a2c8b.png)
