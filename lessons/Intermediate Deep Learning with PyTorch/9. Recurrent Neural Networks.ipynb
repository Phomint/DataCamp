# %% [markdown]
# ## Recurrent neuron
# - Feed-forward networks
# - **RNNs**: have connections pointing back
# - Recurrent neuron:
#     -  Input x
#     -  Output y
#     -  Hidden state h
# - In PyTorch: ```nn.RNN()```
#
# ![image.png](attachment:e6ef5520-32ba-443e-a377-fe770760c97f.png)
#
# ### Unrolling recurrent neuron through time
#
# ![image.png](attachment:4d04f463-fdec-4ea6-8f10-6e587e2985b7.png)
#
# ### Deep RNNs
#
# ![image.png](attachment:8a174544-e7df-47bc-9a16-9f9789f12a0f.png)

# %% [markdown]
# ### RNN in PyTorch
# - Define model class with `__init__` method
# - Define recurrent layer, `self.rnn`
# - Define linear layer, `fc`
# - In `forward()`, initialize first hidden state to zeros
# - Pass input and first hidden state through RNN layer
# - Select last RNN's output and pass it through linear layer

# %%
from torch import nn, zeros

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.rnn = nn.RNN(
            input_size=1,
            hidden_size=32,
            num_layers=2,
            batch_first=True,
        )
        self.fc = nn.Linear(32, 1)

    def forward(self, x):
        h0 = zeros(2, x.size(0), 32)
        out, _ = self.rnn(x, h0)
        out = self.fc(out[:, -1, :])
        return out
