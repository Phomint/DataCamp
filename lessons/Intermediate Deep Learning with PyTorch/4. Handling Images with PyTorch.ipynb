# %% [markdown]
# ## Loading images to PyTorch

# %%
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import transforms

train_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((128, 128))
])

dataset_train = ImageFolder(
    "data/clouds_train",
    transforms=train_transforms
)

# %% [markdown]
# ### Displaying images

# %%
dataloader_train = DataLoader(
    dataset_train,
    shuffle=True,
    batch_size=1
)

image, label = next(iter(dataloader_train))
print(image.shape)

# %% [markdown]
# ![image.png](attachment:18b5b5ab-ad77-4e97-a7b9-768f8c44f625.png)

# %%
image = image.squeeze().permute(1, 2, 0)
print(image.shape)

# %% [markdown]
# ![image.png](attachment:24b7ae8e-9264-4327-8fed-cd600156e87d.png)

# %%
import matplotlib.pyplot as plt
plt.imshow(image)
plt.show()

# %% [markdown]
# ![image.png](attachment:0e0263d6-e211-4cee-b643-efccc3caf0f9.png)

# %% [markdown]
# ### Data augmentation
# Generating more data by applying random transformations to original image
# - Increase the size and diversity of the training set
# - Improve model robustness
# - Reduce overfitting

# %%
train_transforms = transforms.Compose([
    # additional transformations
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(45),

    transforms.ToTensor(),
    transforms.Resize((128, 128))
])

dataset_train = ImageFolder(
    "data/clouds_train",
    transforms=train_transforms
)
